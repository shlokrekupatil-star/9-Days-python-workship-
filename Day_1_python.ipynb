# %%
 print("hello world")
# Out:
# hello world

# %%
print(2+3)
# Out:
# 5

# %%
print(2-3)
# Out:
# -1

# %%
print(4*7)
# Out:
# 28

# %%
print(7/5)
# Out:
# 1.4

# %%
a=10
b=20
print(a+b)+

# %%
a=-20
b=30
print(a*b)
# Out:
# -600

# %%
NGI7a=10
a=20
print(a+a)
# Out:
# 40

# %%
print(10+12-1)
# Out:
# 21

# %%
print(2+5*4)
# Out:
# 22

# %%
a="Hello"
b="world"
print(a+b)
# Out:
# Helloworld

# %%
a="Hello"
b=200
print(a*b)
# Out:
# ...

# %%
a="Hello"
b=30
print(a+b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-402552938.py in <cell line: 0>()
#       1 a="Hello"
#       2 b=30
# ----> 3 print(a+b)
#       4
#
# TypeError: can only concatenate str (not "int") to str

# %%
a="pyton"
b=("*"*3)
print(b+a+b)
# Out:
# ***pyton***

# %%
a=("vasu")
b=len(a)
print(b)
# Out:
# 4

# %%
a=("vasu")
b=len(a)
print("*"*b+a+"*"b)
# Out:
#   File "/tmp/ipython-input-976961316.py", line 3
#     print("*"*b+a+"*"b)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
a=input()
print(a)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3061576234.py in <cell line: 0>()
# ----> 1 a=input()
#       2 print(a)
#       3
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
# ...

# %%
a=int(input())
print(a)
# Out:
# 15.0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-296542073.py in <cell line: 0>()
# ----> 1 a=int(input())
#       2 print(a)
#       3
#
# ValueError: invalid literal for int() with base 10: '15.0'

# %%
a=int(input())
b=int(input())
print(a+b)
# Out:
# 560

# %%
name=input()
print("*"*3+name+"*"*3)
# Out:
# 55
# ***55***

# %%
float_value=float(input("Enter a integer value"))
print(float_value)
# Out:
# Enter a integer value20
# 20.0

# %%
a=input()
b=len(a)
("*"*b+a+"*"*b)
# Out:
# sandesh
# '*******sandesh*******'

# %%
a=(input())
b=(input())
print(a+b)
# Out:
# milkshake
#
# milkshake

# %%
a=(input())
b=(input())
print(a+b)
# Out:
# milk shake
#
# milk shake

# %%
a=(input())
b=(input())
print(a+" "+b)
# Out:
# mil;kshake
#  mil;kshake

# %%
a=input()
b=(input())
print(a+" "+b+" ")
# Out:
# robet is
# 20 year old
# robet is 20 year old

# %%
b=(input())
c=(input())
print (a+" "+b+" "+c
# Out:
#   File "/tmp/ipython-input-516835509.py", line 3
#     print (a+" "+b+" "+c
#                         ^
# SyntaxError: incomplete input

# %%
a=input()
b=int()
print(type(a ))
print(type(b))
# Out:
# <class 'str'>
# <class 'int'>

# %%
a="24"
b=10
c=b+int(a)
print(c)
# Out:
# 34

# %%
fist_name=input()
number=int(input())
print(fist_name+" "+"is"str(number+2)+"year old")
# Out:
#   File "/tmp/ipython-input-3333817579.py", line 3
#     print(fist_name+" "+"is"str(number+2)+"year old")
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
first_namb=input()
second_numb=input()
print("understand the type conversion")
print (int(first_numb)+int(second_numb))
print(first_numb+second_numb)
print(float(first_numb)+float(second_numb))
# Out:
# 2
# 3
# understand the type conversion
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1951330593.py in <cell line: 0>()
#       2 second_numb=input()
#       3 print("understand the type conversion")
# ----> 4 print (int(first_numb)+int(second_numb))
#       5 print(first_numb+second_numb)
#       6 print(float(first_numb)+float(second_numb))
#
# NameError: name 'first_numb' is not defined

# %%
a="KLE hospital"
print(a[4:14])
print(a[:7])
print(a[:3])
print(a[:6])
# Out:
# hospital
# KLE hos
# KLE
# KLE ho

# %%
a="KLE bca engineering"
print(a[4:7])
print(a[:7])
print(a[:3])
# Out:
# bca
# KLE bca
# KLE

# %%
a="kle chikkodi bca"
print(a[4:13])
# Out:
# chikkodi

# %%
a=21
b=str(a)
print(b 1q)

# %%
a=(input())
b=(input())
print(a+" "+b+" ")
# Out:
# happy
# coding
# happy coding

# %%
a=(input())
b=(input())
print(a+" "+b+" ")
# Out:
# teach
# foundation
# teach foundation

# %%
a=int(input())
b=str(a)
print(b[0])
print(b[3])
# Out:
# 1456
# 1
# 6

# %%
a=int(input())
b=str(a)
print(b[0])
print(b[-1])
# Out:
# 12345
# 1
# 5

# %%
number=12345
c_in-string=str(number)
first_char=c_in_string[0]
last_char=c_in_string[-1]
print(int(first_char)+int(last_char))
# Out:
#   File "/tmp/ipython-input-3067022042.py", line 2
#     c_in-string=str(number)
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
a=(input())
print(len(a))

# %%
a=input()
b=str()
print(a)
# Out:
# pyton
# pyton

# %%
a=input()
b=a[0:4]
print(b*2)
# Out:
# pyhon
# pyhopyho

# %%
name=input()
part=name[0:3]
print(part)
# Out:
# kle bca collage
# kle

# %%
a=int(input())
b=int(input())
print(2*(a+b))
# Out:
# 2
# 4
# 12

# %%
print()
# Out:
#   File "/tmp/ipython-input-1934180297.py", line 1
#     print(a*b>130 abd(a*bc130))
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
 totaa=int(input())
 b=int(input())l
 print("primenter of rectangle is:+str(total)")
# Out:
# 2
# 4
# primenter of rectangle is:+str(total)

# %%
print("#"*1)
print("#"*2)
print("#"*3)
# Out:
# #
# ##
# ###

# %%
a=input()
 b=a[-1]
 c=a[-2]
 print(int(b)+int(c))
# Out:
#   File "/tmp/ipython-input-2929685513.py", line 2
#     b=a[-1]
#     ^
# IndentationError: unexpected indent

# %%
a=15
b=2

print(a+b)
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a%b)
print(a**b)
# Out:
# 17
# 17
# 13
# 30
# 7.5
# 1
# 225

# %%
a=13
b=33
print(a<b)
print(a>b)
print(a==b)
print(a!=b)
print(a>=b)
print(a<=b)
# Out:
# True
# False
# False
# True
# False
# True

# %%
a=True
b=False
print(a and b)
print(a or b)
print(not a)
# Out:
# False
# True
# False

# %%
m=int(input())
p=int(input())
c=int(input())
print(m>60 and p>50 and c>45 and m+p+c>180)
print(m+p>=120 or c+p>=110)
# Out:
# 50
# 60
# 70
# False
# True

# %%
a=input()
b=input()
c=a[-3:]
d=b[-3:]
print(a==b)
# Out:
# pyton
# pyton
# True

# %%
a="vasu"
print("the name is matching")
print("the name is not maching")
print("the name is not maching")
print("the name is not maching")
# Out:
# the name is matching
# the name is not maching
# the name is not maching
# the name is not maching

# %%
a=10
b=10
if a==b:
  print("both value is mached")
# Out:
# both value is mached

# %%
a=input()
b=input()
if len(a)==len(b):
           print("condtion is true")
print("program ended")
# Out:
# python
# python
# condtion is true
# program ended

# %%
a=int(input())
if a:0
print("the number is positive")
# Out:
# 15
# the number is positive

# %%
number=int(input())
if number>0:
  print("the number is positive")
print("program ended")
# Out:
# 10
# the number is positive
# program ended

# %%
number=int(input())
if a>2:
  print("the number is even")
print("program ended")
# Out:
# 10
# the number is even
# program ended

# %%
a=input("enter password:")
if a == "python":
  print("correct password")
# Out:
# enter password:python
# correct password

# %%
a=int(input())
if a >0:
  print("positive")
else:
   print("not positive")
print("end")
# Out:
# -87
# not positive
# end

# %%
a=input(" ")
if a == "python":
  print("correct password")
else:
  print("not mathing")
  print("program ended")
# Out:
#  sandesh
# not mathing
# program ended

# %%
input
# Out:
# <bound method Kernel.raw_input of <google.colab._kernel.Kernel object at 0x784ed0f58a40>>

# %%
age=int(input("enter your age:"))
if age >= 18:
  print("you are eligibal to vote")
  print("not eligibal for vote")
# Out:
# enter your age:24
# you are eligibal to vote
# not eligibal for vote

# %%
num=int(input("enter a number:"))
if num % 2 == 0:
 print("even number")
else:
  print("odd number")
# Out:
# even number

# %%
a=input()
b=input()
if a[0:3]==b[:3]:
  print("matched")
else:
  print ("not matched")
# Out:
# python
# python
# matched

# %%
      a=input()
b=input()
if a[0:3]==b[:-1]:
  print("matched")
else:
  print ("not matched")
# Out:
# python
# python
# not matched

# %%
a
# Out:
#   File "/tmp/ipython-input-892054079.py", line 3
#     if (s=="large and < >300")
#                               ^
# SyntaxError: expected ':'

# %%
a=int(input())
b=int(input ())
if(a>300 and a+b<500):
  print("can  a team up")
else:
  print("can not a team up")
# Out:
# 200
# 499
# can not a team up

# %%
a=int(input())
b=int(input())
if((a and b)>=1000 or b>500):
    print("pair")
else:
    print("not pair")
# Out:
# 500
# 570
# pair

# %%
a=int(input())
if (a<=10):
    print(a+1)
else:
  print(n+5)
# Out:
# 10
# 11

# %%
a=int(input())
b=int(input())
c=int(input())
if(a+b+c==180):
  print("*"*1)
  print("*"*2)
  print("*"*3)
else:
  print("not vaild trianle")
# Out:
# 60
# 70
# 80
# not vaild trianle

# %%
a=int(input())
b=int(input())
sum=a+b
if((a<20 and b<20) or(sum<20)):
  print(sum)
else:
  print(a)
  print(b)
# Out:
# 50
# 67
# 50
# 67

# %%
a=int(input())
b=int(input())
sum=a+b
if((a<20 and b<20) or(30<sum<50)):
  print(sum)
else:
  print(a)
  print(b)
# Out:
# 35
# 235
# 35
# 235
