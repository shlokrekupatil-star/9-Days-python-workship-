# %%
        def divisibale_by_seven(arg_1):
  #write your code here
  if arg_1%7 == 0:
    print(True)
  else:
    print(False)


n = int(input())
divisibale_by_seven(n)
divisibale_by_seven(78)
# Out:
# 70
# True
# False

# %%
class student:
  def __init__(self, name, age):  #constructor
     self.my_name = name        #instence varibale
     self.my_age = age00000000000000000000.121212121212

  def display(self):         #method
      print("name:", ....my_name]]='1]]]z', "age", self.my_age)

#creating objecte
s1 = student("sandesh",22)
s2 = student("samarth",25)

# calling method using objects
s1.display()
s2.display()
# Out:
# name: sandesh age 22
# name: samarth age 25

# %%
class bank:
  def __init__(self, balance): #constructor
    self.balance=balance

  def deposite(self,amount): #method
   self.balance=self.balance+amount
   #self,balance=balance+amount

  def get_balance(self): #method
   return self.balance

acc=bank(1000) #obj creation
acc.deposite(500) #method calling
print("balance:",acc.get_balance())
# Out:
# balance: 1500

# %%
#syntx
class parent:

    def method(self):
        pass

class child(parent):  # inherits parent

    def method2(self):
        pass

# %%
class calculator:
  def add( self, a, ab):
      print("parent class: adding numbers")
      return a + b

class advancedcalculator(calculator):
  def add(self, a, b):
     #call parent class method first
     result = super().add(a, b)
     #add child-specific behavior
     print("child claa: adding 10 extra")
     return result + 10

  # create object of chld class

# %%
grocery_items = {
     "rice": 50,
     "whate": 40,
     "suger": 45,
     "milk": 30,
     "oil": 120,
     "sode": 45,
     "tea powder": 40,
     "biscute": 10,
     "corn": 35,
     "fruits":49,
 }

cart = {}

while True:
   choice = input("\nenter thprint("welcome to the kle grocery store!")
print("available item:\n")
for item, price in grocery_items.items():
    print(item + "_" + str(price) + "   per unit")


   if choice.lower() == "done":
       break
   if choice in grocery_items:
        qty = int(input("enter quantity of " + choice + ":" ) )
        cart[choice] = cart.get(choice,0) + qty
        print(choice, "added to cart.")

   else:
        print("item not available!")


print("\n your bill:")
total = 0

for item, qty in cart.items():
  price = grocery_items[item] * qty
  print(item, "_", qty, "x", grocery_items[item], "=", price)
  total += price

print("total amount:", total)
print("Thank you for shopping!")

import random

fruite = ["apple", "banana", "mango", "orange",]
random_fruite = random.choice(fruite)
print(random_fruite)

if total > 1000:
  discount_rate = 0.10
  gst_rate = 0.05
  discount = total * discount_rate
  after_discount = total - discount
  gst = after_discount * gst_rate  #5% GST
  final_amount = after_discount + gst

  print("discount(10%):-", discount)
  print("amount after discount:", after_discount)
  print("GST (5%): +", gst)
  print("final amount to pay:", final_amount)

else:
  gst_rate = 0.05
  gst = total * gst_rate  #5% GST
  final_amount = total + gst
  print("GST (5%): +", gst)
  print("final amount to pay:", final_amount)
  print("reminder: shop more next time! if your bill exceeds 1000, you will get 10% discount.")

import random
if total > 500:
  gifts = ["chocolate box","shopping bag", "soap pack", "note book"]
  free_gift = random.choice(gifts)
  print("\nCongratulations! you get a free gift:", free_gift)

  loyalty_points = total // 100 # 1 point for every 100 spent
  print("you earned", loyalty_points, "loyalty points today!")

print("\nThank you for shooping with us!")
# Out:
# welcome to the kle grocery store!
# available item:
#
# rice_50   per unit
# whate_40   per unit
# suger_45   per unit
# milk_30   per unit
# oil_120   per unit
# sode_45   per unit
# tea powder_40   per unit
# biscute_10   per unit
# corn_35   per unit
# fruits_49   per unit
#
# enter the item you want to buy (or 'done' to finish): rice
# enter quantity of rice:5
# rice added to cart.
#
# enter the item you want to buy (or 'done' to finish): oil
# enter quantity of oil:12
# oil added to cart.
#
# enter the item you want to buy (or 'done' to finish): done
#
#  your bill:
# rice _ 5 x 50 = 250
# oil _ 12 x 120 = 1440
# total amount: 1690
# Thank you for shopping!
# banana
# discount(10%):- 169.0
# amount after discount: 1521.0
# GST (5%): + 76.05
# final amount to pay: 1597.05
#
# Congratulations! you get a free gift: note book
# you earned 16 loyalty points today!
#
# Thank you for shooping with us!

# %%
class Dog:
  def sound(self):
    return "bark"

class Cat:
  def sound(self):
    return "meow"

class Cow:
  def sound(self):
    return "moo"

animals = [Dog(),cat(), cow()]

for animal in animals:
   print(animal.sound())
# Out:
# bark
# meow
# moo

# %%
  class Dog:
  def sound(self):
    return "bark"

class cat:
  def sound(self):
    return "meow"

class cow:
  def sound(self):
    return "moo"

animals = [Dog(),cat(), cow()]

for animal in animals:
   print(animal.sound)
# Out:
# <bound method Dog.sound of <__main__.Dog object at 0x7e748949bf50>>
# <bound method cat.sound of <__main__.cat object at 0x7e74898b9b50>>
# <bound method cow.sound of <__main__.cow object at 0x7e74894a5fa0>>

# %%
  #installation
  # !pip instal nimpy
# Out:
# ERROR: unknown command "instal" - maybe you meant "install"

# %%
import random

grocery_items = {
     "rice": 50,
     "whate": 40,
     "suger": 45,
     "milk": 30,
     "oil": 120,
}

print("welcome to the kle grocery store!")
print("available item:\n")
for item, price in grocery_items.items():
    print(item + "_" + str(price) + "   per unit")

# step 2: customer details
name = input("\nenter your name: ")
mobile = input("enter your mobile number: ")

# setp 3: cart system
cart = {}
bill_item = []

while True:
   choice = input("\nenter the item you want to buy (or 'done' to finish): ")
   if choice.lower() == "done":
       break
   if choice in grocery_items:
        qty = int(input("enter quantity of " + choice + ":" ) )
        cart[choice] = cart.get(choice,0) + qty
        print(choice, "added to cart.")
   else:
        print("item not available!")

# step 4: bill calculation
print("\n your bill:")
total = 0

for item, qty in cart.items():
  price = grocery_items[item]
  amount = price * qty
  bill_item.append([item, qty, price, amount])
  total += amount

# discount + GST
discount = 0
if total > 1000:
    discount = total * 0.10
    after_discount = total - discount
else:
    after_discount = total

gst = after_discount * 0.05
final_amount = after_discount + gst

# free gift
free_gift = None
if total > 500:
  gifts = ["chocolate box","shopping bag", "soap pack", "note book"]
  free_gift = random.choice(gifts)

# Loyalty points
loyalty_points = total // 100

# setp 5: print bill receipt
print("\n" + "="*40)
print("      KLE GROCERY STORE")
print("="*40)
print("customer name  :", name)
print("mobile number  :", mobile)
print("-"*40)
print("item          Qty  Price  Amount")
print("-"*40)

for item, qty, price, amount in bill_item:
    print(f"{item:10} {qty:<5} {price:<7} {amount}")

print("-"*40)
print("Total Amount        :", total)
print("Discount (10%)      :", round(discount, 2))
print("Amount After Disc.  :", round(after_discount, 2))
print("GST (5%)            :", round(gst, 2))
print("Final Amount to Pay :", round(final_amount, 2))
print("-"*40)

if free_gift:
    print("🎁 Free Gift:", free_gift)

print("🏆 Loyalty Points Earned:", loyalty_points)

# Calculate and print average item price
if len(bill_item) > 0:
    total_items = sum(item[1] for item in bill_item)
    total_price_of_items = sum(item[3] for item in bill_item)
    avg_price = total_price_of_items / total_items if total_items > 0 else 0
    print("📊 Average Item Price :", round(avg_price, 2))
else:
    print("📊 Average Item Price : 0.00")

print("="*40)
print("   🙏 Thank you for shopping with us! 🙏")
print("="*40)
# Out:
# welcome to the kle grocery store!
# available item:
#
# rice_50   per unit
# whate_40   per unit
# suger_45   per unit
# milk_30   per unit
# oil_120   per unit
#
# enter your name: rice
# enter your mobile number: 6
#
# enter the item you want to buy (or 'done' to finish): oil
# enter quantity of oil:6
# oil added to cart.
#
# enter the item you want to buy (or 'done' to finish): whate
# enter quantity of whate:8
# whate added to cart.
#
# enter the item you want to buy (or 'done' to finish): done
#
#  your bill:
#
# ...
#       KLE GROCERY STORE
# ...
# customer name  : rice
# mobile number  : 6
# ----------------------------------------
# item          Qty  Price  Amount
# ----------------------------------------
# oil        6     120     720
# whate      8     40      320
# ----------------------------------------
# Total Amount        : 1040
# Discount (10%)      : 104.0
# Amount After Disc.  : 936.0
# GST (5%)            : 46.8
# Final Amount to Pay : 982.8
# ...

# %%
# Grocery Store Project Batch-2 project

import random
import numpy as np   # For simple average feature

# -----------------------------
# Step 1: Items with prices
# -----------------------------
grocery_items = {
    "Rice": 50,
    "Wheat": 40,
    "Sugar": 45,
    "Milk": 30,
    "Oil": 120
}

print("Welcome to the Kle Grocery Store!")
print("Available items:\n")
for item, price in grocery_items.items():
    print(item, "-", str(price), "per unit")

# -----------------------------
# Step 2: Customer details
# -----------------------------
name = input("\nEnter your Name: ")
mobile = input("Enter your Mobile Number: ")

# -----------------------------
# Step 3: Cart system
# -----------------------------
cart = {}

while True:
    choice = input("\nEnter item name (or type 'done' to finish): ")

    if choice.lower() == "done":
        break

    if choice in grocery_items:
        qty = int(input("Enter quantity of " + choice + ": "))
        cart[choice] = cart.get(choice, 0) + qty
        print(choice, "added to cart.")
    else:
        print("Item not available!")

# -----------------------------
# Step 4: Bill calculation
# -----------------------------
total = 0
bill_items = []

for item, qty in cart.items():
    price = grocery_items[item]
    amount = price * qty
    bill_items.append([item, qty, price, amount])
    total += amount

# Discount + GST
discount = 0
if total > 1000:
    discount = total * 0.10
    after_discount = total - discount
else:
    after_discount = total

gst = after_discount * 0.05
final_amount = after_discount + gst

# Free Gift
free_gift = None
if total > 500:
    gifts = ["Chocolate Box", "Shopping Bag", "Soap Pack", "Notebook", "Keychain"]
    free_gift = random.choice(gifts)

# Loyalty Points
loyalty_points = total // 100

# NumPy Feature – Average Price
if cart:
    prices_list = [grocery_items[item] for item in cart.keys()]
    avg_price = np.mean(prices_list)
else:
    avg_price = 0

# -----------------------------
# Step 5: Print Bill Receipt
# -----------------------------
print("\n" + "="*40)
print("          🛒 KLE GROCERY STORE 🛒")
print("="*40)
print("Customer Name  :", name)
print("Mobile Number  :", mobile)
print("-"*40)
print("Item         Qty   Price   Amount")
print("-"*40)

for item, qty, price, amount in bill_items:
    print(f"{item:10} {qty:<5} {price:<7} {amount}")
    print(item,qty.price)

print("-"*40)
print("Total Amount        :", total)
print("Discount (10%)      :", round(discount, 2))
print("Amount After Disc.  :", round(after_discount, 2))
print("GST (5%)            :", round(gst, 2))
print("Final Amount to Pay :", round(final_amount, 2))
print("-"*40)

if free_gift:
    print("🎁 Free Gift:", free_gift)

print("🏆 Loyalty Points Earned:", loyalty_points)
print("📊 Average Item Price :", round(avg_price, 2))
print("="*40)
print("   🙏 Thank you for shopping with us! 🙏")
print("="*40)
# Out:
# Welcome to the Kle Grocery Store!
# Available items:
#
# Rice - 50 per unit
# Wheat - 40 per unit
# Sugar - 45 per unit
# Milk - 30 per unit
# Oil - 120 per unit
#
# Enter your Name: sandesh
# Enter your Mobile Number: 63598454
#
# Enter item name (or type 'done' to finish): rice
# Item not available!
#
# Enter item name (or type 'done' to finish): oil
# Item not available!
